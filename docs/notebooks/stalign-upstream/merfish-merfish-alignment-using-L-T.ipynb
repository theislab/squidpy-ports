# %% [markdown]
# # STalign parity: `merfish-merfish-alignment-using-L-T.ipynb`
#
# Executed one-to-one replay of [the pinned upstream notebook](https://github.com/JEFworks-Lab/STalign/blob/b2068edc98974efa54537eca194736e177bbe11d/docs/notebooks/merfish-merfish-alignment-using-L-T.ipynb).
#
# Status: `compared`. The notebook's second fit uses the stale `A, v, xv = LDDMM(...)` tuple API, which upstream no longer returns. The replay supplies a result that unpacks both ways, so both of its fits are compared. Both passes skipped 7 cell(s) unrelated to the fit -- cell 25: TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.; cell 27: TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.; cell 31: TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.; cell 32: TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.; cell 34: TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.; cell 47: TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.; cell 51: TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
from squidpy_ports.stalign.notebook_suite import compare_notebook

result = compare_notebook("merfish-merfish-alignment-using-L-T.ipynb")
result.metrics
# Out:
# {
#   "A relative L2": 0.0,
#   "AI relative L2": 0.0,
#   "L relative L2": 0.0,
#   "extentI relative L2": 0.0,
#   "extentJ relative L2": 0.0,
#   "levels relative L2": 0.0,
#   "phi relative L2": 5.289809229150516e-07,
#   "phiI relative L2": 1.1191575146694763e-05,
#   "phii relative L2": 4.6784411317517205e-07,
#   "phiiJ relative L2": 1.2683542838215957e-05,
#   "source_L relative L2": 0.0,
#   "tpointsI relative L2": 4.6152925924412134e-07,
#   "xI_L relative L2": 0.0,
#   "xI_LDDMM relative L2": 2.669952518320691e-07,
#   "xI_L_T relative L2": 0.0,
#   "yI_L relative L2": 0.0,
#   "yI_LDDMM relative L2": 5.877015044782997e-07,
#   "yI_L_T relative L2": 0.0
# }

# %%
result.figures[0]
# Out:
# <upstream vs Squidpy, figure 1>

# %%
result.figures[1]
# Out:
# <upstream vs Squidpy, figure 2>

# %%
result.figures[2]
# Out:
# <upstream vs Squidpy, figure 3>

# %%
result.figures[3]
# Out:
# <upstream vs Squidpy, figure 4>

# %%
result.figures[4]
# Out:
# <upstream vs Squidpy, figure 5>

# %%
result.figures[5]
# Out:
# <upstream vs Squidpy, figure 6>

# %%
result.figures[6]
# Out:
# <upstream vs Squidpy, figure 7>

# %%
result.figures[7]
# Out:
# <upstream vs Squidpy, figure 8>

# %%
result.figures[8]
# Out:
# <upstream vs Squidpy, figure 9>

# %%
result.figures[9]
# Out:
# <upstream vs Squidpy, figure 10>
