# %% [markdown]
# # STalign parity: `merfish-merfish-alignment-using-L-T.ipynb`
#
# Executed one-to-one replay of [the pinned upstream notebook](https://github.com/JEFworks-Lab/STalign/blob/b2068edc98974efa54537eca194736e177bbe11d/docs/notebooks/merfish-merfish-alignment-using-L-T.ipynb).
#
# Status: `compared`. The notebook's second fit uses the stale `A, v, xv = LDDMM(...)` tuple API. The suite compares its first complete 10,000-iteration fit.

# %%
from squidpy_ports.stalign.notebook_suite import compare_notebook
result = compare_notebook('merfish-merfish-alignment-using-L-T.ipynb')
result.metrics
# Out:
# {
#   "aligned points median |delta|": 0.002068755657169187,
#   "aligned points p95 |delta|": 0.004940117659855204,
#   "aligned points relative L2": 3.8398562918737556e-07,
#   "matching weights max |delta|": 1.1102230246251565e-16,
#   "matching weights relative L2": 2.8817268677123666e-19,
#   "warped density relative L2": 1.12639175761563e-05
# }

# %%
result.figure
# Out:
# <STalign parity comparison figure>
