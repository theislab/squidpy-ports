# %% [markdown]
# # STalign parity: `heart-alignment.ipynb`
#
# Executed one-to-one replay of [the pinned upstream notebook](https://github.com/JEFworks-Lab/STalign/blob/b2068edc98974efa54537eca194736e177bbe11d/docs/notebooks/heart-alignment.ipynb).
#
# Status: `compared`.

# %%
from squidpy_ports.stalign.notebook_suite import compare_notebook
result = compare_notebook('heart-alignment.ipynb')
result.metrics
# Out:
# {
#   "aligned points median |delta|": 0.022128602238643307,
#   "aligned points p95 |delta|": 0.02806378801121423,
#   "aligned points relative L2": 1.1311371582589875e-06,
#   "matching weights max |delta|": 8.992806499463768e-15,
#   "matching weights relative L2": 1.9363272120337046e-16,
#   "warped density relative L2": 2.032917075289471e-05
# }

# %%
result.figure
# Out:
# <STalign parity comparison figure>
