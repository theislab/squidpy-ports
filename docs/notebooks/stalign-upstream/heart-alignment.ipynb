# %% [markdown]
# # STalign parity: `heart-alignment.ipynb`
#
# Executed one-to-one replay of [the pinned upstream notebook](https://github.com/JEFworks-Lab/STalign/blob/b2068edc98974efa54537eca194736e177bbe11d/docs/notebooks/heart-alignment.ipynb).
#
# Status: `compared`.

# %%
# per-variable relative L2: upstream STalign vs the squidpy JAX port
# Out:
# {
#   "A relative L2": 4.876082298168759e-05,
#   "df1[acronym] label disagreement": 0.0,
#   "df1[acronym] label set jaccard": 1.0,
#   "df1[acronym] labels only squidpy": 0.0,
#   "df1[acronym] labels only upstream": 0.0,
#   "df1[color] label disagreement": 0.0,
#   "df1[color] label set jaccard": 1.0,
#   "df1[color] labels only squidpy": 0.0,
#   "df1[color] labels only upstream": 0.0,
#   "df1[id] median abs delta": 0.0,
#   "df1[image] label disagreement": 0.0,
#   "df1[image] label set jaccard": 1.0,
#   "df1[image] labels only squidpy": 0.0,
#   "df1[image] labels only upstream": 0.0,
#   "df1[intensity] median abs delta": 0.0,
#   "df1[right.left] median abs delta": 0.0,
#   "df1[rostral.caudal] median abs delta": 0.0,
#   "df1[spot.id] median abs delta": 0.0,
#   "df1[x] median abs delta": 0.0,
#   "df1[y] median abs delta": 0.0,
#   "df2[acronym] label disagreement": 0.0,
#   "df2[acronym] label set jaccard": 1.0,
#   "df2[acronym] labels only squidpy": 0.0,
#   "df2[acronym] labels only upstream": 0.0,
#   "df2[color] label disagreement": 0.0,
#   "df2[color] label set jaccard": 1.0,
#   "df2[color] labels only squidpy": 0.0,
#   "df2[color] labels only upstream": 0.0,
#   "df2[id] median abs delta": 0.0,
#   "df2[image] label disagreement": 0.0,
#   "df2[image] label set jaccard": 1.0,
#   "df2[image] labels only squidpy": 0.0,
#   "df2[image] labels only upstream": 0.0,
#   "df2[intensity] median abs delta": 0.0,
#   "df2[right.left] median abs delta": 0.0,
#   "df2[rostral.caudal] median abs delta": 0.0,
#   "df2[spot.id] median abs delta": 0.0,
#   "df2[x] median abs delta": 0.0,
#   "df2[y] median abs delta": 0.0,
#   "extentI relative L2": 0.0,
#   "extentJ relative L2": 0.0,
#   "levels relative L2": 0.0,
#   "phi relative L2": 1.252623327294869e-06,
#   "phiI relative L2": 2.0331723079719106e-05,
#   "phii relative L2": 1.1736298494554168e-06,
#   "phiiJ relative L2": 2.012998525881673e-05,
#   "results relative L2": 1.1726181919921905e-06,
#   "tpointsI relative L2": 0.0,
#   "tpointsJ relative L2": 1.1726181919921905e-06,
#   "v relative L2": 3.946693745154862e-15
# }

# %%
# get cell centroid coordinates
xI = np.array(df1['x'])
yI = np.array(df1['y'])

# plot
fig,ax = plt.subplots()
ax.scatter(xI,yI,s=1,alpha=0.2)
# Out:
# <upstream (left) vs squidpy (right), figure 1>

# %%
# rasterize at 100um resolution so image looks smooth
XI,YI,I,fig = STalign.rasterize(xI,yI,dx=100)

# plot
ax = fig.axes[0]
ax.invert_yaxis()
# Out:
# <upstream (left) vs squidpy (right), figure 2>

# %%
# get cell centroids
xJ = np.array(df2['x'])
yJ = np.array(df2['y'])

# plot
fig,ax = plt.subplots()
ax.scatter(xJ,yJ,s=1,alpha=0.2,c='#ff7f0e')
# Out:
# <upstream (left) vs squidpy (right), figure 3>

# %%
# rasterize and plot
XJ,YJ,J,fig = STalign.rasterize(xJ,yJ,dx=100)
ax = fig.axes[0]
ax.invert_yaxis()
# Out:
# <upstream (left) vs squidpy (right), figure 4>

# %%
# plot
fig,ax = plt.subplots()
ax.scatter(xI,yI,s=1,alpha=0.1)
ax.scatter(xJ,yJ,s=1,alpha=0.2)
# Out:
# <upstream (left) vs squidpy (right), figure 5>

# %%
# get extent of images
extentI = STalign.extent_from_x((YI,XI))
extentJ = STalign.extent_from_x((YJ,XJ))

# plot rasterized images
fig,ax = plt.subplots(2,1)
ax[0].imshow((I.transpose(1,2,0).squeeze()), extent=extentI) 
ax[1].imshow((J.transpose(1,2,0).squeeze()), extent=extentJ) 
ax[0].invert_yaxis()
ax[1].invert_yaxis()
# Out:
# <upstream (left) vs squidpy (right), figure 6>

# %%
# apply transform
phii = STalign.build_transform(xv,v,A,XJ=[YJ,XJ],direction='b')
phiI = STalign.transform_image_source_to_target(xv,v,A,[YI,XI],Ifoo,[YJ,XJ])


#switch tensor from cuda to cpu for plotting with numpy
if phii.is_cuda:
    phii = phii.cpu()
if phiI.is_cuda:
    phiI = phiI.cpu()

# plot with grids
fig,ax = plt.subplots()
levels = np.arange(-100000,100000,1000)
ax.contour(XJ,YJ,phii[...,0],colors='r',linestyles='-',levels=levels)
ax.contour(XJ,YJ,phii[...,1],colors='g',linestyles='-',levels=levels)
ax.set_aspect('equal')
ax.set_title('source to target')
ax.imshow(phiI.permute(1,2,0)/torch.max(phiI),extent=extentJ)
ax.invert_yaxis()
# Out:
# <upstream (left) vs squidpy (right), figure 7>

# %%
# transform is invertible
phi = STalign.build_transform(xv,v,A,XJ=[YI,XI],direction='f')
phiiJ = STalign.transform_image_target_to_source(xv,v,A,[YJ,XJ],Jfoo,[YI,XI])

#switch tensor from cuda to cpu for plotting with numpy
if phi.is_cuda:
    phi = phi.cpu()
if phiiJ.is_cuda:
    phiiJ = phiiJ.cpu()

# plot with grids
fig,ax = plt.subplots()
levels = np.arange(-100000,100000,1000)
ax.contour(XI,YI,phi[...,0],colors='r',linestyles='-',levels=levels)
ax.contour(XI,YI,phi[...,1],colors='g',linestyles='-',levels=levels)
ax.set_aspect('equal')
ax.set_title('target to source')
ax.imshow(phiiJ.permute(1,2,0)/torch.max(phiiJ),extent=extentI)
ax.invert_yaxis()
# Out:
# <upstream (left) vs squidpy (right), figure 8>

# %%
# plot results
fig,ax = plt.subplots()
ax.scatter(tpointsI[0,:],tpointsI[1,:],s=1,alpha=0.1) 
ax.scatter(tpointsJ[:,1],tpointsJ[:,0],s=1,alpha=0.2) # also needs to plot as y,x not x,y
# Out:
# <upstream (left) vs squidpy (right), figure 9>
