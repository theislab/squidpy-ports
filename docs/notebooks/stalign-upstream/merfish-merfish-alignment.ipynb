# %% [markdown]
# # STalign parity: `merfish-merfish-alignment.ipynb`
#
# Executed one-to-one replay of [the pinned upstream notebook](https://github.com/JEFworks-Lab/STalign/blob/b2068edc98974efa54537eca194736e177bbe11d/docs/notebooks/merfish-merfish-alignment.ipynb).
#
# Status: `compared`.

# %%
from squidpy_ports.stalign.notebook_suite import compare_notebook
result = compare_notebook('merfish-merfish-alignment.ipynb')
result.metrics
# Out:
# {
#   "aligned points median |delta|": 0.0012531617324027904,
#   "aligned points p95 |delta|": 0.0030103721159384154,
#   "aligned points relative L2": 2.380919389405317e-07,
#   "matching weights max |delta|": 1.1102230246251565e-16,
#   "matching weights relative L2": 3.3249822014875416e-19,
#   "warped density relative L2": 2.074304639188436e-06
# }

# %%
result.figure
# Out:
# <STalign parity comparison figure>
