# %% [markdown]
# # STalign parity: `merfish-merfish-alignment.ipynb`
#
# Executed one-to-one replay of [the pinned upstream notebook](https://github.com/JEFworks-Lab/STalign/blob/b2068edc98974efa54537eca194736e177bbe11d/docs/notebooks/merfish-merfish-alignment.ipynb).
#
# Status: `compared`.

# %%
from squidpy_ports.stalign.notebook_suite import compare_notebook

result = compare_notebook("merfish-merfish-alignment.ipynb")
result.metrics
# Out:
# {
#   "A relative L2": 9.841786065083767e-06,
#   "L relative L2": 0.0,
#   "df3 relative L2": 1.8186266933431902e-07,
#   "extentI relative L2": 0.0,
#   "extentJ relative L2": 0.0,
#   "levels relative L2": 0.0,
#   "phi relative L2": 2.0011940409459177e-07,
#   "phiI relative L2": 2.0824860286319993e-06,
#   "phii relative L2": 2.0076100046839647e-07,
#   "phiiJ relative L2": 2.3840466329433395e-06,
#   "source_L relative L2": 0.0,
#   "tpointsI relative L2": 1.8186266933431902e-07,
#   "v relative L2": 5.466788737009652e-15,
#   "xI_L relative L2": 0.0,
#   "xI_LDDMM relative L2": 2.5956443775895987e-07,
#   "xI_L_T relative L2": 0.0,
#   "yI_L relative L2": 0.0,
#   "yI_LDDMM relative L2": 2.9296594954409204e-08,
#   "yI_L_T relative L2": 0.0
# }

# %%
result.figures[0]
# Out:
# <upstream vs Squidpy, figure 1>

# %%
result.figures[1]
# Out:
# <upstream vs Squidpy, figure 2>

# %%
result.figures[2]
# Out:
# <upstream vs Squidpy, figure 3>

# %%
result.figures[3]
# Out:
# <upstream vs Squidpy, figure 4>

# %%
result.figures[4]
# Out:
# <upstream vs Squidpy, figure 5>

# %%
result.figures[5]
# Out:
# <upstream vs Squidpy, figure 6>

# %%
result.figures[6]
# Out:
# <upstream vs Squidpy, figure 7>

# %%
result.figures[7]
# Out:
# <upstream vs Squidpy, figure 8>

# %%
result.figures[8]
# Out:
# <upstream vs Squidpy, figure 9>

# %%
result.figures[9]
# Out:
# <upstream vs Squidpy, figure 10>

# %%
result.figures[10]
# Out:
# <upstream vs Squidpy, figure 11>
