# %% [markdown]
# # STalign parity: `merfish-merfish-alignment-affine-only-with-points.ipynb`
#
# Executed one-to-one replay of [the pinned upstream notebook](https://github.com/JEFworks-Lab/STalign/blob/b2068edc98974efa54537eca194736e177bbe11d/docs/notebooks/merfish-merfish-alignment-affine-only-with-points.ipynb).
#
# Status: `compared-affine`.

# %%
from squidpy_ports.stalign.notebook_suite import compare_notebook

result = compare_notebook("merfish-merfish-alignment-affine-only-with-points.ipynb")
result.metrics
# Out:
# {
#   "affine linear relative L2": 0.0034826207297185656,
#   "affine translation relative L2": 0.0037151724250676643,
#   "aligned landmarks median |delta|": 7.097734755854643,
#   "squidpy landmark residual": 645.0019415939927,
#   "upstream landmark residual": 644.2610972745791
# }

# %%
result.figure
# Out:
# <STalign parity comparison figure>
