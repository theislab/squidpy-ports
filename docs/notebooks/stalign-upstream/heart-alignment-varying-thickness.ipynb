# %% [markdown]
# # STalign parity: `heart-alignment-varying-thickness.ipynb`
#
# Executed one-to-one replay of [the pinned upstream notebook](https://github.com/JEFworks-Lab/STalign/blob/b2068edc98974efa54537eca194736e177bbe11d/docs/notebooks/heart-alignment-varying-thickness.ipynb).
#
# Status: `compared`.

# %%
from squidpy_ports.stalign.notebook_suite import compare_notebook

result = compare_notebook("heart-alignment-varying-thickness.ipynb")
result.metrics
# Out:
# {
#   "A relative L2": 2.4435876801168148e-05,
#   "extentI relative L2": 0.0,
#   "extentJ relative L2": 0.0,
#   "levels relative L2": 0.0,
#   "phi relative L2": 7.998811118279164e-07,
#   "phiI relative L2": 1.4800442717872193e-05,
#   "phii relative L2": 8.035938620556275e-07,
#   "phiiJ relative L2": 1.4162855879083896e-05,
#   "tpointsI relative L2": 0.0,
#   "tpointsJ relative L2": 8.386648304668232e-07,
#   "v relative L2": 1.0513390225069248e-15
# }

# %%
result.figures[0]
# Out:
# <upstream vs Squidpy, figure 1>

# %%
result.figures[1]
# Out:
# <upstream vs Squidpy, figure 2>

# %%
result.figures[2]
# Out:
# <upstream vs Squidpy, figure 3>

# %%
result.figures[3]
# Out:
# <upstream vs Squidpy, figure 4>

# %%
result.figures[4]
# Out:
# <upstream vs Squidpy, figure 5>

# %%
result.figures[5]
# Out:
# <upstream vs Squidpy, figure 6>

# %%
result.figures[6]
# Out:
# <upstream vs Squidpy, figure 7>

# %%
result.figures[7]
# Out:
# <upstream vs Squidpy, figure 8>

# %%
result.figures[8]
# Out:
# <upstream vs Squidpy, figure 9>
