# %% [markdown]
# # STalign parity: `heart-alignment-varying-thickness.ipynb`
#
# One-to-one replay of [the pinned upstream notebook](https://github.com/JEFworks-Lab/STalign/blob/b2068edc98974efa54537eca194736e177bbe11d/docs/notebooks/heart-alignment-varying-thickness.ipynb). Its preprocessing and fit arguments are executed directly from the vendored notebook; the captured fit is then run with upstream PyTorch and Squidpy JAX.

# %%
from squidpy_ports.stalign.notebook_suite import compare_notebook

result = compare_notebook("heart-alignment-varying-thickness.ipynb")
result.metrics

# %%
result.figure
